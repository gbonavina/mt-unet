# %%
# %pip install --quiet torch torchvision

# %%
# !git clone https://github.com/gbonavina/mt-unet
import sys
sys.path.insert(0, "/content/mt-unet")
# Out:
# Cloning into 'mt-unet'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 27 (delta 2), reused 25 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 3.63 MiB | 38.34 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pathlib import Path

ARCHIVE = Path("/content/drive/MyDrive/casia2-processed.tar.gz")
DEST = Path("/content/data/processed")
DEST.mkdir(parents=True, exist_ok=True)

# !tar -xzf {ARCHIVE} -C {DEST}

PROCESSED = DEST / "casia2"
print(list(PROCESSED.iterdir())[:8])
# Out:
# [PosixPath('/content/data/processed/casia2/masks'), PosixPath('/content/data/processed/casia2/val.csv'), PosixPath('/content/data/processed/casia2/summary.json'), PosixPath('/content/data/processed/casia2/train.csv'), PosixPath('/content/data/processed/casia2/pairing_audit.json'), PosixPath('/content/data/processed/casia2/test.csv'), PosixPath('/content/data/processed/casia2/images')]

# %%
from src.data import CASIA2Dataset

train = CASIA2Dataset(PROCESSED, split="train")
val = CASIA2Dataset(PROCESSED, split="val")
test = CASIA2Dataset(PROCESSED, split="test")
print(len(train), len(val), len(test))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3131/4022730651.py in <cell line: 0>()
# ----> 1 from src.data import CASIA2Dataset
#       2
#       3 train = CASIA2Dataset(PROCESSED, split="train")
#       4 val = CASIA2Dataset(PROCESSED, split="val")
#       5 test = CASIA2Dataset(PROCESSED, split="test")
#
# ModuleNotFoundError: No module named 'src.data'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from src.model import MT_UNET

model = MT_UNET()
history = model.fit(train, val, epochs=50, batch_size=8)
# Out:
# train 1/50:   0%|          | 1/1104 [00:14<4:32:08, 14.80s/it]
